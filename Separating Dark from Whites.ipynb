# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as img_

# %%
path=r"C:\Users\Asus\Desktop\7x Camera\IMG_20180430_192711.jpg"

# %%
img= img_.imread(path)

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (3456, 4608, 3)

# %%
print(img)
# Out:
# [[[ 6  6  4]
#   [ 6  6  4]
#   [ 7  7  5]
#   ...
#   [25 29 15]
#   [24 28 14]
#   [19 23  9]]
#
#  [[ 5  5  3]
#   [ 6  6  4]
#   [ 7  7  5]
#   ...
#   [22 28 14]
#   [23 29 15]
#   [20 26 12]]
#
#  [[ 3  3  1]
#   [ 6  6  4]
#   [ 7  7  5]
#   ...
#   [21 27 13]
#   [23 29 15]
#   [20 26 12]]
#
#  ...
#
#  [[19 15 16]
#   [17 13 14]
#   [16 12 13]
#   ...
#   [ 8  4  3]
#   [ 9  5  4]
#   [10  6  5]]
#
#  [[14 10 11]
#   [13  9 10]
#   [14 10 11]
#   ...
#   [ 7  3  2]
#   [ 9  5  4]
#   [11  7  6]]
#
#  [[12  8  9]
#   [13  9 10]
#   [15 11 12]
#   ...
#   [ 7  3  2]
#   [ 8  4  3]
#   [10  6  5]]]

# %%
import numpy as np

# %%
import cv2

# %%
img_viridis= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_viridis)

# %%
print(img_viridis.shape)
# Out:
# (3456, 4608)

# %%
img_bnw= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_bnw, cmap='gray')

# %%
print(img_bnw.shape)
# Out:
# (3456, 4608)

# %%
print(img_bnw)
# Out:
# [[ 5  5  6 ... 24 23 18]
#  [ 4  5  6 ... 23 24 21]
#  [ 2  5  6 ... 22 24 21]
#  ...
#  [16 14 13 ...  4  5  6]
#  [11 10 11 ...  3  5  7]
#  [ 9 10 12 ...  3  4  6]]

# %%
import sys

# %%
np.set_printoptions(threshold=sys.maxsize)
img_bnw

# %%
img_bnw.max()
# Out:
# 255

# %%
result=img_bnw<245

# %%
img_bnw[result]=0

# %%
plt.imshow(img_bnw, cmap='gray')
